# %%
import sys
import pandas as pd
import numpy as np

# %%
sys.path.append("../dataloader")
from dataloader import daigtv2_loader
sys.path.append("../part1")

# %%
data = daigtv2_loader("~/Desktop/ISyE4600_Machine_Learning/ISyE4600 Project/")

# %%
data
# Out:
#                                                     text  label  \
# 0      Phones\n\nModern humans today are always on th...      0
# 1      This essay will explain if drivers should or s...      0
# 2      Driving while the use of cellular devices\n\nT...      0
# 3      Phones & Driving\n\nDrivers should not be able...      0
# 4      Cell Phone Operation While Driving\n\nThe abil...      0
# ...                                                  ...    ...
# 44863  Dear Senator,\n\nI am writing to you today to ...      1
# 44864  Dear Senator,\n\nI am writing to you today to ...      1
# 44865  Dear Senator,\n\nI am writing to you today to ...      1
# 44866  Dear Senator,\n\nI am writing to you today to ...      1
# 44867  Dear Senator,\n\nI am writing to you today to ...      1
#
#                             prompt_name           source  RDizzl3_seven
# 0                    Phones and driving  persuade_corpus          False
# 1                    Phones and driving  persuade_corpus          False
# 2                    Phones and driving  persuade_corpus          False
# 3                    Phones and driving  persuade_corpus          False
# 4                    Phones and driving  persuade_corpus          False
# ...                                 ...              ...            ...
# 44863  Does the electoral college work?    kingki19_palm           True
# 44864  Does the electoral college work?    kingki19_palm           True
# 44865  Does the electoral college work?    kingki19_palm           True
# 44866  Does the electoral college work?    kingki19_palm           True
# 44867  Does the electoral college work?    kingki19_palm           True
#
# [44868 rows x 5 columns]

# %%
from sklearn.model_selection import train_test_split

train, test = train_test_split(data, test_size=0.2, random_state=42)

# %%
train
# Out:
#                                                     text  label  \
# 5233   Luke seems to like the program, because you he...      0
# 28816  One strategy business are increasingly adoptin...      1
# 1550   Imagine this you're in a very populated city. ...      0
# 1888   People tend to use there cars so much, they ba...      0
# 16987  Driveless cars can be a very great enhancement...      0
# ...                                                  ...    ...
# 11284  I believe that using this technology could be ...      0
# 44732  Dear Senator,\n\nI am writing to you today to ...      1
# 38158  Despite the many hurdles we must all face when...      1
# 860    Texting & Driving\n\nUsing your phone while dr...      0
# 15795  Dear Principal,\n\nI have been really good thi...      0
#
#                                  prompt_name           source  RDizzl3_seven
# 5233           "A Cowboy Who Rode the Waves"  persuade_corpus           True
# 28816                      Distance learning    chat_gpt_moth          False
# 1550                         Car-free cities  persuade_corpus           True
# 1888                         Car-free cities  persuade_corpus           True
# 16987                        Driverless cars  persuade_corpus           True
# ...                                      ...              ...            ...
# 11284            Facial action coding system  persuade_corpus           True
# 44732       Does the electoral college work?    kingki19_palm           True
# 38158              Seeking multiple opinions    chat_gpt_moth          False
# 860                       Phones and driving  persuade_corpus          False
# 15795  Grades for extracurricular activities  persuade_corpus          False
#
# [35894 rows x 5 columns]
